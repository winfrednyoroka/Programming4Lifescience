# %%
# reading contents of a file
with open("/Users/wgatua/Documents/HackBio/Programming4Lifescience/Data/sequence.fasta","r") as myfile:
    line=myfile.readlines()
    for i in line:
        #print(i)
        if i.startswith(">"):
            continue
        C_count=i.count("C")
    print(C_count)
# Out:
# 5

# %%
pwd
# Out:
# '/Users/wgatua'
