# %%
dna="actgactagactag"
dna=dna.upper()

# %%
def GCperc(n):
    C_count=dna.count("C")
    G_count=dna.count("G")
    GC_count=C_count+G_count
    return ((GC_count/len(dna))*100)

# %%
GCperc(dna)
# Out:
# 42.857142857142854
